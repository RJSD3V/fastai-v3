# %% [markdown]
# <a href="https://colab.research.google.com/github/RJSD3V/fastai-v3/blob/master/Classifying_Spotted_Big_Cats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Big Cat Diary ImageNet.
# #### My life-long love for big cats has been the inspiration behind this project. I've taken images from a website called image-net.org, consisting of images of spotted jaguars, leopards and snow leopards. It would possibly be impossible to get a high accuracy rating in classifying these images, because the threee animals look very similar. Possisbly wit using image resolutions higher than 224, there might be a chance to classify based on the facial cues, shape of the spots, and subtle differences in skeletal structure.

# %% [markdown]
# Using the techniques showed in fastai course Part1 Lesson 2.

# %%
from fastai.vision import *

# %%
# !pip uninstall torch torchvision -y
# !pip install torch==1.4.0 torchvision==0.5.0
# Out:
# Uninstalling torch-1.5.0+cu101:
#   Successfully uninstalled torch-1.5.0+cu101
# Uninstalling torchvision-0.6.0+cu101:
#   Successfully uninstalled torchvision-0.6.0+cu101
# ...
#      |████████████████████████████████| 753.4MB 20kB/s
# ...
#      |████████████████████████████████| 4.0MB 35.7MB/s
# ...

# %%
folder='tigris'
file='tigris.csv'

# %%
folder='pardus'
file='pardus.csv'

# %%
folder='uncia'
file='uncia.csv'

# %%
path = Path('/big_cat_data/')

# %%
path.ls()
# Out:
# [PosixPath('/big_cat_data/pardus'),
#  PosixPath('/big_cat_data/tigris'),
#  PosixPath('/big_cat_data/uncia'),
#  PosixPath('/big_cat_data/.ipynb_checkpoints')]

# %%
classes = ['pardus','uncia','tigris']

# %%
for i in classes:
  file=i+'.csv'
  dest=path/i
  download_images(path/i/file, dest, max_pics=500)
# Out:
# Error http://www.animalzoom.org/fotos/leopard1.jpg HTTPConnectionPool(host='www.animalzoom.org', port=80): Max retries exceeded with url: /fotos/leopard1.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fde6fbbeba8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error http://content.answers.com/main/content/wp/en/thumb/9/9d/180px-Amur_Leopard_With_Scraps_of_Food.gif HTTPConnectionPool(host='content.answers.com', port=80): Max retries exceeded with url: /main/content/wp/en/thumb/9/9d/180px-Amur_Leopard_With_Scraps_of_Food.gif (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fde6fbbd780>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# ...

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# pardus
# cannot identify image file <_io.BufferedReader name='/big_cat_data/pardus/00000186.jpg'>
# cannot identify image file <_io.BufferedReader name='/big_cat_data/pardus/00000396.jpg'>
# cannot identify image file <_io.BufferedReader name='/big_cat_data/pardus/00000486.JPG'>
# cannot identify image file <_io.BufferedReader name='/big_cat_data/pardus/00000194.jpg'>
# cannot identify image file <_io.BufferedReader name='/big_cat_data/pardus/00000368.jpg'>
# cannot identify image file <_io.BufferedReader name='/big_cat_data/pardus/00000287.jpg'>
# cannot identify image file <_io.BufferedReader name='/big_cat_data/pardus/00000352.jpg'>
# cannot identify image file <_io.BufferedReader name='/big_cat_data/pardus/00000092.jpg'>
# cannot identify image file <_io.BufferedReader name='/big_cat_data/pardus/00000402.jpg'>
# cannot identify image file <_io.BufferedReader name='/big_cat_data/pardus/00000390.jpg'>
# ...

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
data.classes
# Out:
# ['pardus', 'tigris', 'uncia']

# %%
data.show_batch(rows=30,figsize=(7,8))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['pardus', 'tigris', 'uncia'], 3, 690, 172)

# %%
learn = cnn_learner(data, models.resnet34, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.054263</td>
#       <td>0.253503</td>
#       <td>0.953488</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.047978</td>
#       <td>0.249452</td>
#       <td>0.953488</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.065619</td>
#       <td>0.243777</td>
#       <td>0.947674</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.067930</td>
#       <td>0.232910</td>
#       <td>0.947674</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.057177</td>
#       <td>0.247670</td>
#       <td>0.953488</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1')

# %%
learn.export()

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [5/10 01:01<01:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
# If the plot is not showing try to give a start and end learning rate
# learn.lr_find(start_lr=1e-5, end_lr=1e-1)
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, max_lr=slice(1e-7,1e-6))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.052266</td>
#       <td>0.259178</td>
#       <td>0.947674</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.034142</td>
#       <td>0.263826</td>
#       <td>0.947674</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.030420</td>
#       <td>0.262963</td>
#       <td>0.947674</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.033891</td>
#       <td>0.256625</td>
#       <td>0.947674</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.031490</td>
#       <td>0.254565</td>
#       <td>0.947674</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.export()

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
interp.plot_confusion_matrix()

# %%
defaults.device=torch.device('cpu')

# %%
img=open_image(path/'1200px-Leopard_africa.jpg')
learn=load_learner(path)
pred_class,pred_idx,outputs=learn.predict(img)
print(pred_class)
# Out:
# pardus
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
